# %% [markdown]
# <a href="https://colab.research.google.com/github/Thitiphorn267-3/python_dataviz2023/blob/main/%E0%B8%95%E0%B8%B4%E0%B8%A7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx')
region = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=1)
result_constituencies_PartyList = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=2)
result_constituencies_Candidate = pd.read_excel('/content/drive/MyDrive/ติว/ectreport2023_มีภาค (1).xlsx',sheet_name=3)
result_constituencies_status = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=4)
info_province = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=5)
info_party_overview = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=6)
info_constituency = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=7)
Candidate_Constituency = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=8)
Candidate_PartyList = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=9)
Candidate_PM = pd.read_excel('/content/drive/MyDrive/ติว/Copy of ectreport2023_มีภาค.xlsx',sheet_name=10)

# %%
for_thai = pd.read_csv('/content/drive/MyDrive/ติว/Copy of creditcard_2023.csv',index_col = 0)
for_thai
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# id
# 0      -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1       0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2      -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3      -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4      -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454 -0.370393
# 568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148 -0.016935
# 568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098 -0.070958
# 568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148  0.580568
# 568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493 -0.347613
#
# ...

# %%
result_constituencies_Candidate[result_constituencies_Candidate['mp_app_vote_percent']>100] #ดูdataแบบมีเงื่อนไข
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 2593   NST_6   NST_6_1            5         5596            146.37719
# 2594   NST_6  NST_6_10            4         7731            202.22338
# 2601   NST_6   NST_6_4            6         5574            145.80173
# 2602   NST_6   NST_6_5            1        27331            714.90976
# 2605   NST_6   NST_6_8            3        10700            279.88491
# 2606   NST_6   NST_6_9            2        23260            608.42270
#
#       party_id  Unnamed: 6  Unnamed: 7  Unnamed: 8
# 2593       705         NaN         NaN         NaN
# 2594       763         NaN         NaN         NaN
# 2601       701         NaN         NaN         NaN
# 2602       743         NaN         NaN         NaN
# 2605       726         NaN         NaN         NaN
# 2606       709         NaN         NaN         NaN

# %% [markdown]
# #วิธีการดู่า null

# %%
info_party_overview.isnull().any() # เอาข้อมูลมาorกัน
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool

# %%
info_party_overview[info_party_overview.isnull().any()]

# %% [markdown]
# # วิธี fill na

# %%
fill_na_sasa = info_party_overview.fillna('99')

# %%
fill_na_sasa[fill_na_sasa['party_no'] == '99'] # อยากเห็นข้อมูล ไม่จำเป็นต้องทำ
# Out:
#      id party_no          name  abbr    color  \
# 9   711       99  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       99     พลังบูรพา   พบ.  #4696d6
# 17  720       99     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %%
result_constituencies_Candidate.describe()
# Out:
#        mp_app_rank   mp_app_vote  mp_app_vote_percent     party_id  \
# count  4781.000000   4781.000000          4781.000000  4781.000000
# mean      6.711985   7654.289898             8.223124   733.349090
# std       3.845837  12389.868008            19.185614    23.968199
# min       1.000000      0.000000             0.000000   701.000000
# 25%       3.000000    300.000000             0.309190   709.000000
# 50%       6.000000    780.000000             0.809330   729.000000
# 75%      10.000000  11738.000000            12.227910   762.000000
# max      20.000000  63185.000000           714.909760   786.000000
#
#        Unnamed: 6  Unnamed: 7  Unnamed: 8
# count         0.0         0.0         1.0
# mean          NaN         NaN     38275.0
# std           NaN         NaN         NaN
# min           NaN         NaN     38275.0
# 25%           NaN         NaN     38275.0
# 50%           NaN         NaN     38275.0
# 75%           NaN         NaN     38275.0
# ...

# %% [markdown]
# # วิธีการ join merge

# %%
con_id1 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_1']
con_id2 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_2']
con_id3 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_3']

# %%
con_id1
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %%
con_id2
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 13   ACR_2   ACR_2_1            2        19188             17.16080       726
# 14   ACR_2  ACR_2_10            1        46881             41.92804       709
# 15   ACR_2  ACR_2_11           11          193              0.17261       742
# 16   ACR_2  ACR_2_12           12          173              0.15472       770
# 17   ACR_2   ACR_2_2            6         2027              1.81285       762
# 18   ACR_2   ACR_2_3            3        17637             15.77366       705
# 19   ACR_2   ACR_2_4           10          197              0.17619       712
# 20   ACR_2   ACR_2_5            5         2530              2.26271       701
# 21   ACR_2   ACR_2_6            8          519              0.46417       719
# 22   ACR_2   ACR_2_7            7         1156              1.03387       763
# 23   ACR_2   ACR_2_8            9          378              0.33806       769
# ...

# %%
contest = pd.concat([con_id1, con_id2]) # การต่อท้ายตาราง

# %%
contest
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %% [markdown]
# # Join

# %% [markdown]
# ตารางซ้าย .merge (ตารางขวา, left_on = 'colเป็นpK',how = 'left' (ซ้ายหลัก ขวารอง)

# %%
con_id1.merge(Candidate_Constituency, on = 'mp_app_id', how='left')
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %% [markdown]
# #วิธีลบคำซ้ำ

# %%
x1 = con_id1.merge(Candidate_Constituency, on = 'mp_app_id', how='left')

# %%
x1.merge(info_constituency, on = 'cons_id', how='left')
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1   ACR_1_1            9          459              0.43477       706
# 2    ACR_1  ACR_1_10            1        38275             36.25419       709
# 3    ACR_1  ACR_1_10            1        38275             36.25419       709
# 4    ACR_1  ACR_1_11           13          126              0.11935       712
# 5    ACR_1  ACR_1_11           13          126              0.11935       712
# 6    ACR_1  ACR_1_12           12          127              0.12029       742
# 7    ACR_1  ACR_1_12           12          127              0.12029       742
# 8    ACR_1  ACR_1_13           11          212              0.20081       761
# 9    ACR_1  ACR_1_13           11          212              0.20081       761
# 10   ACR_1   ACR_1_2           10          234              0.22165       769
# ...

# %%
x2 = x1.merge(info_constituency, on = 'cons_id', how='left')

# %%
x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 3    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 5    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 7    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 9    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 11   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# ...

# %%
x3 = x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]

# %%
x3
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 3    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 5    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 7    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 9    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 11   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# ...

# %%
# making a bool series
bool_series = x3.duplicated(subset='mp_app_name')
# passing NOT of bool series to see unique values only
x4 = x3[~bool_series]
# displaying data
x5 = x4.reset_index()

# %%
x5
# Out:
#     index cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0       0   ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1       2   ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 2       4   ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 3       6   ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 4       8   ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 5      10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 6      12   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 7      14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 8      16   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 9      18   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 10     20   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# ...

# %% [markdown]
# #วิธีการสร้าง data frame

# %%
y ={
    'LOL' : ['sc','sa','si','gh','jk','lg','fg','jg','kn','lj','fd','ng']
}

# %%
lol = pd.DataFrame(y)
lol
# Out:
#    LOL
# 0   sc
# 1   sa
# 2   si
# 3   gh
# 4   jk
# 5   lg
# 6   fg
# 7   jg
# 8   kn
# 9   lj
# 10  fd
# 11  ng

# %%
xlol = x5.join(lol,how = 'left')

# %%
xlol
# Out:
#     index cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0       0   ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1       2   ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 2       4   ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 3       6   ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 4       8   ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 5      10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 6      12   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 7      14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 8      16   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 9      18   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 10     20   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# ...

# %% [markdown]
# #gropby

# %%
contest.groupby('cons_id')['mp_app_vote','mp_app_id'].max().reset_index()
# Out:
# <ipython-input-67-672b69d51260>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   contest.groupby('cons_id')['mp_app_vote','mp_app_id'].max().reset_index()
#   cons_id  mp_app_vote mp_app_id
# 0   ACR_1        38275   ACR_1_9
# 1   ACR_2        46881   ACR_2_9

# %%
contest.groupby('cons_id')[['mp_app_vote','mp_app_id']].max().reset_index().sort_values(by = 'mp_app_vote',ascending = False) # เรียงข้อมูลมากไปมาก เลือกคอลัมป์
# Out:
#   cons_id  mp_app_vote mp_app_id
# 1   ACR_2        46881   ACR_2_9
# 0   ACR_1        38275   ACR_1_9

# %% [markdown]
# สสเขตแต่ละเขต รหัสเขต ชื่อสส จังหวัด พรรคที่สังกัด คะแนนเสียง เปอร์เซ็น

# %%
result_constituencies_Candidate
